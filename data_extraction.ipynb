# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/movingAvg_N10.csv', index_col=0)

df.head()
# Out:
#       ewt0    ewt1      ewt2      ewt3      ewt4     ewt5      ewt6      ewt7  \
# 0  0.56856 -0.0095 -0.004093 -0.003375  0.011191 -0.01996 -0.008625 -0.000916
# 1  0.56856 -0.0095 -0.004093 -0.003375  0.011191 -0.01996 -0.008625 -0.000916
# 2  0.56856 -0.0095 -0.004093 -0.003375  0.011191 -0.01996 -0.008625 -0.000916
# 3  0.56856 -0.0095 -0.004093 -0.003375  0.011191 -0.01996 -0.008625 -0.000916
# 4  0.56856 -0.0095 -0.004093 -0.003375  0.011191 -0.01996 -0.008625 -0.000916
#
#        ewt8      ewt9  original  sum_without_last
# 0  0.030470  0.041161  0.596716          0.563752
# 1  0.030470  0.041197  0.596751          0.563752
# 2  0.030470  0.041217  0.596771          0.563752
# 3  0.030470  0.041218  0.596772          0.563752
# 4  0.030469  0.041218  0.596772          0.563752

# %%
import matplotlib.pyplot as plt

n = 0
nstr = 'ewt{}'.format(n)
print(nstr)

series = df[nstr].values
plt.plot(series)
# Out:
# ewt0

# %%
np.savetxt('data/{}.txt'.format(nstr), series)
